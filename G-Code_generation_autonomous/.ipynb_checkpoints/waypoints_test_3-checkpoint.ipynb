# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# plot waypoints
def plot_waypoints(waypoints):
    # ----------- plot figure --------------- 
    plt.figure(figsize=(8, 8))
    for i in range(len(waypoints) - 1):
        point1 = [waypoints[i][0], waypoints[i+1][0]]
        point2 = [waypoints[i][1], waypoints[i+1][1]]
        plt.plot(point1, point2, '-o', lw=2.0, color='blue')

    for i in range(100):
        x_o = np.linspace(0, 34, 100)
        y_o = i*wv - (wv/wh)*x_o
        plt.plot(x_o, y_o, '--', color='black', alpha=0.25)
    
        
#     plt.hlines(0, 0, L, lw = 3.0, color='red')
#     plt.vlines(0, 0, W, lw = 3.0, color='red')
#     plt.hlines(L, 0, L, lw = 3.0, color='red')
#     plt.vlines(W, 0, W, lw = 3.0, color='red')

    x = [i for i in range(35)]
    plt.xticks(x, x)
    x = [i for i in range(35)]
    plt.yticks(x, x)
    
    plt.xlim([-1, L+1])
    plt.ylim([-1, W+1])
    
    plt.show()
    
    
def prim_op(wh, wv, W, L):
    h_cond, v_cond = True, True
    line = 1
    while h_cond and v_cond:
            if line % 2 != 0:
                waypoints.append([min(line*wh, L), 0])
                waypoints.append([0, min(line*wv, W)])
            else:
                waypoints.append([0, min(line*wv, W)])
                waypoints.append([min(line*wh, L), 0])
            line += 1
            h_cond = line*wh <= L
            v_cond = line*wv <= W        
    return h_cond, v_cond, line

def horiz_op(line, idx_h, idx_v, ph, pv, W, L):
    # vertically exceed the limit
    ph = (line*wv - W) / np.tan(theta_rad)
    h_cond, v_cond = True, True
    while h_cond and v_cond:    
        if line % 2 == 0:
            waypoints.append([ph + idx_h*wh, W])
            waypoints.append([line*wh, 0])
        else: 
            waypoints.append([line*wh, 0])
            waypoints.append([ph + idx_h*wh, W])

        idx_h += 1
        line += 1
        h_cond = (ph + idx_h*wh) <= L
        v_cond = line*wh <= L

    return h_cond, v_cond, line, ph, idx_h, idx_v
    
    
        
def vert_op(line, idx_h, idx_v, ph, pv, W, L):
    # horizontally exceed the limit
    pv = (line*wh - L) * np.tan(theta_rad) 
    h_cond, v_cond = True, True
    while h_cond and v_cond:
        if line % 2 == 0:
            waypoints.append([ph + idx_h*wh, L])
            waypoints.append([W, pv + idx_v*wv])
        else: 
            waypoints.append([W, pv + idx_v*wv])
            waypoints.append([ph + idx_h*wh, L])

        idx_v += 1
        idx_h += 1
        line += 1
        break_line = line
        h_cond = ph + idx_h*wh <= L 
        v_cond = pv + idx_v <= W
    
    return h_cond, v_cond, line, pv, idx_h, idx_v

# %%
# -------------------------------------
# input variables        
lxy = 3.0  # PnC unit cell spacing (mm) 
theta = 45
# PnC filament orintation (degrees)
L = 34.0  # PnC length (mm)
W = 34.0   # PnC width (mm)

# calcul0ate distance between first two waypoints
theta_rad = theta * np.pi/180
wh = lxy / np.sin(theta_rad)
wv = lxy / np.cos(theta_rad)
# ---------------------------------

waypoints = [[0, 0]]
idx_h, idx_v = 0, 0
horiz, vert = True, True
horiz_new, vert_new = True, True
ph, pv = 0, 0

for i in range(75):
    if horiz and vert:
        if i % 2 != 0:            
            waypoints.append([min(i*wh, L), 0])
            waypoints.append([0, min(i*wv, W)])
        else:
            waypoints.append([0, min(i*wv, W)])
            waypoints.append([min(i*wh, L), 0])
        break_line = i   
        ph = max(((i+1)*wv - W)/np.tan(theta_rad), 0)
        pv = max(((i+1)*wh - L) * np.tan(theta_rad), 0)
        
        horiz = (i+1)*wh <= L
        vert = (i+1)*wv <= W
            
    elif not vert and horiz:
        
        if horiz_new and horiz: 
            if i % 2 == 0:
                waypoints.append([ph + idx_h*wh, W])
                waypoints.append([i*wh, 0])
            else: 
                waypoints.append([i*wh, 0])
                waypoints.append([ph + idx_h*wh, W])
            idx_h += 1
            pv = ((i+1)*wh - L) * np.tan(theta_rad)             
            horiz_new = ph + idx_h*wh <= L
            horiz = (i+1)*wh <= L
            vert_new = pv + idx_v*wv <= L


    elif not horiz and vert:
        if vert_new and vert:
            if i % 2 == 0:
                waypoints.append([ph + idx_h*wh, i*wv])
                waypoints.append([L, pv + idx_v*wv])
            else: 
                waypoints.append([L, pv + idx_v*wv])
                waypoints.append([ph + idx_h*wh, i*wv])

            idx_v += 1
            vert = (i+1)*wv <= W
            vert_new = pv + idx_v*wv <= W
            horiz_new = ph + idx_h*wh <= L
            ph = max(((i+1)*wv - W)/np.tan(theta_rad), 0)
            
    elif not horiz and not vert:
        if horiz_new and vert_new:
            if i % 2 == 0:
                waypoints.append([ph + idx_h*wh, W])
                waypoints.append([L, pv + idx_v*wv])
            else: 
                waypoints.append([L, pv + idx_v*wv])
                waypoints.append([ph + idx_h*wh, L])
            idx_v += 1
            idx_h +=1 
            horiz_new = ph + idx_h*wh <= L
            vert_new = pv + idx_v*wv <= L


        
plot_waypoints(waypoints)

# %%
vert
# Out:
# False

# %%
# -------------------------------------
# input variables        
lxy = 3.0  # PnC unit cell spacing (mm) 
theta = 60  # PnC filament orintation (degrees)
L = 34.0  # PnC length (mm)
W = 34.0   # PnC width (mm)

# calcul0ate distance between first two waypoints
theta_rad = theta * np.pi/180
wh = lxy / np.sin(theta_rad)
wv = lxy / np.cos(theta_rad)
# ---------------------------------

waypoints = [[0, 0]]
line = 1
idx_h = 0
idx_v = 0
h_cond = 0
h_line, v_line = 0, 0
break_h, break_v = False, False   # initialize with false


while line*wh <= L and line*wv <= W:
        if line % 2 != 0:
            waypoints.append([line*wh, 0])
            waypoints.append([0, line*wv])
        else:
            waypoints.append([0, line*wv])
            waypoints.append([line*wh, 0])
            
        line += 1
        break_line = line

        
# vertically exceed the limit
ph = (break_line*wv - W) / np.tan(theta_rad)

while (ph + idx_h*wh) <= L and line*wh <= L:    
    if line % 2 == 0:
        waypoints.append([ph + idx_h*wh, W])
        waypoints.append([line*wh, 0])
    else: 
        waypoints.append([line*wh, 0])
        waypoints.append([ph + idx_h*wh, W])

    idx_h += 1
    line += 1
    break_line = line
        

# horizontally exceed the limit
pv = (line*wh - L) * np.tan(theta_rad) 
for i in range(6):
    if line % 2 == 0:
        waypoints.append([ph + idx_h*wh, W])
        waypoints.append([L, pv + idx_v*wv])
    else: 
        waypoints.append([L, pv + idx_v*wv])
        waypoints.append([ph + idx_h*wh, W])
    
    idx_v += 1
    idx_h += 1
    line += 1
    break_line = line
    
    

        
#         if line % 2 == 0:
#             waypoints.append([h_cond, W])
#             waypoints.append([L, v_cond])
#         elif line % 2 != 0:
#             waypoints.append([L, v_cond])
#             waypoints.append([h_cond, W])
#         idx_v += 1
#         idx_h += 1


plot_waypoints(waypoints)
