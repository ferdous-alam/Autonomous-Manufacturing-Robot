# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# Bruteforce solution for checking logic
# input variables
lxy = 3.0  # PnC unit cell spacing (mm) 
theta = 30  # PnC filament orintation (degrees)
L = 34.0  # PnC length (mm)
W = 34.0   # PnC width (mm)

# calculate distance between first two waypoints
theta_rad = theta * np.pi/180
wh = 2 * lxy * np.sin(theta_rad)   # converting angles from degrees to radians
wv = 2 * lxy * np.cos(theta_rad)   # converting angles from degrees to radians


# initialization
waypoints = [[0, 0], [wh, 0]]   # initial waypoints


# left half
waypoints.append([0, 1*wv])   # p1
waypoints.append([0, 2*wv])   # p2
waypoints.append([2*wh, 0])   # p3
waypoints.append([3*wh, 0])   # p4
waypoints.append([0, 3*wv])   # p5
waypoints.append([0, 4*wv])   # p6
waypoints.append([4*wh, 0])   # p7
waypoints.append([5*wh, 0])   # p8
waypoints.append([0, 5*wv])   # p9
waypoints.append([0, 6*wv])   # p10
waypoints.append([6*wh, 0])   # p11
waypoints.append([7*wh, 0])   # p12

# right half
d = (7*wv-W)*np.tan(theta_rad)
waypoints.append([d, W])      # p13
waypoints.append([d+wh, W])   # p14
waypoints.append([8*wh, 0])   # p15
waypoints.append([9*wh, 0])   # p16
waypoints.append([d+2*wh, W]) # p17
waypoints.append([d+3*wh, W]) # p18
waypoints.append([10*wh, 0])  # p19
waypoints.append([11*wh, 0])  # p20
waypoints.append([d+4*wh, W]) # p21
waypoints.append([d+5*wh, W]) # p22

p =  
waypoints.append([L, p])      # p23
waypoints.append([L, p+wv])   # p24
waypoints.append([d+6*wh, W]) # p25
waypoints.append([d+7*wh, W]) # p26
waypoints.append([L, p+2*wv]) # p27
waypoints.append([L, p+3*wv]) # p28
waypoints.append([d+8*wh, W]) # p29
waypoints.append([d+9*wh, W]) # p30
waypoints.append([L, p+4*wv]) # p31
waypoints.append([L, p+5*wv]) # p32
waypoints.append([d+10*wh, W])# p33
waypoints.append([d+11*wh, W])# p34
    


# ----------- plot figure --------------- 
plt.figure(figsize=(12, 12))
for i in range(len(waypoints) - 1):
    point1 = [waypoints[i][0], waypoints[i+1][0]]
    point2 = [waypoints[i][1], waypoints[i+1][1]]
    plt.plot(point1, point2, '-o', color='black')

# plt.hlines(0, 0, L, lw = 3.0, color='red')
# plt.vlines(0, 0, W, lw = 3.0, color='red')
plt.hlines(L, 0, L, lw = 3.0, color='red')
# plt.vlines(W, 0, W, lw = 3.0, color='red')

x = [i for i in range(35)]
plt.xticks(x, x)
x = [i for i in range(35)]
plt.yticks(x, x)
plt.show()
# Out:
#   File "<ipython-input-5-ed4007221bd1>", line 45
#     p =
#          ^
# SyntaxError: invalid syntax

# %%
(7*wv-W)/np.tan(theta_rad)

# %%
# Bruteforce solution for checking logic
# input variables
lxy = 3.0  # PnC unit cell spacing (mm) 
theta = 30  # PnC filament orintation (degrees)
L = 34.0  # PnC length (mm)
W = 34.0   # PnC width (mm)

# calculate distance between first two waypoints
theta_rad = theta * np.pi/180
wh = 2 * lxy * np.sin(theta_rad)   # converting angles from degrees to radians
wv = 2 * lxy * np.cos(theta_rad)   # converting angles from degrees to radians


# initialization
waypoints = [[0, 0], [wh, 0]]   # initial waypoints


# left half
waypoints.append([0, 1*wv])   # p1
waypoints.append([0, 2*wv])   # p2
waypoints.append([2*wh, 0])   # p3
waypoints.append([3*wh, 0])   # p4
waypoints.append([0, 3*wv])   # p5
waypoints.append([0, 4*wv])   # p6
waypoints.append([4*wh, 0])   # p7
waypoints.append([5*wh, 0])   # p8
waypoints.append([0, 5*wv])   # p9
waypoints.append([0, 6*wv])   # p10
waypoints.append([6*wh, 0])   # p11
waypoints.append([7*wh, 0])   # p12

# right half
d = (7*wv-W)*np.tan(theta_rad)
waypoints.append([d, W])      # p13
waypoints.append([d+wh, W])   # p14
waypoints.append([8*wh, 0])   # p15
waypoints.append([9*wh, 0])   # p16
waypoints.append([d+2*wh, W]) # p17
waypoints.append([d+3*wh, W]) # p18
waypoints.append([10*wh, 0])  # p19
waypoints.append([11*wh, 0])  # p20
waypoints.append([d+4*wh, W]) # p21
waypoints.append([d+5*wh, W]) # p22

p = (13*wh-L)*np.tan(theta_rad)
waypoints.append([L, p])      # p23
waypoints.append([L, p+wv])   # p24
waypoints.append([d+6*wh, W]) # p25
waypoints.append([d+7*wh, W]) # p26
waypoints.append([L, p+2*wv]) # p27
waypoints.append([L, p+3*wv]) # p28
waypoints.append([d+8*wh, W]) # p29
waypoints.append([d+9*wh, W]) # p30
waypoints.append([L, p+4*wv]) # p31
waypoints.append([L, p+5*wv]) # p32
waypoints.append([d+10*wh, W])# p33
waypoints.append([d+11*wh, W])# p34
    


# ----------- plot figure --------------- 
plt.figure(figsize=(12, 12))
for i in range(len(waypoints) - 1):
    point1 = [waypoints[i][0], waypoints[i+1][0]]
    point2 = [waypoints[i][1], waypoints[i+1][1]]
    plt.plot(point1, point2, '-o', color='black')

# plt.hlines(0, 0, L, lw = 3.0, color='red')
# plt.vlines(0, 0, W, lw = 3.0, color='red')
plt.hlines(L, 0, L, lw = 3.0, color='red')
# plt.vlines(W, 0, W, lw = 3.0, color='red')

x = [i for i in range(35)]
plt.xticks(x, x)
x = [i for i in range(35)]
plt.yticks(x, x)
plt.show()

# %%
# input variables
lxy = 3.0  # PnC unit cell spacing (mm) 
theta = 30  # PnC filament orintation (degrees)
L = 34.0  # PnC length (mm)
W = 34.0   # PnC width (mm)

# calculate distance between first two waypoints
theta_rad = theta * np.pi/180
wh = 2 * lxy * np.sin(theta_rad)   # converting angles from degrees to radians
wv = 2 * lxy * np.cos(theta_rad)   # converting angles from degrees to radians


waypoints = [[0, 0], [wh, 0]]   # initial waypoints

idx = 1
while True:
    if idx * wv > L:
        break
    cond = 0
    waypoints.append([0, idx*wv])
    if (idx+1) * wv > L:
        break
    cond = 1
    waypoints.append([0, (idx+1)*wv])
    if (idx+1) * wh > W:
        break
    cond = 2
    waypoints.append([(idx+1)*wh, 0])
    if (idx+2) * wh > W:
         break
    cond = 3
    waypoints.append([(idx+2)*wh, 0])
    idx += 2


d = (7*wv-W)*np.tan(theta_rad)
waypoints.append([d, W])
waypoints.append([d+wh, W])
waypoints.append([8*wh, 0])
waypoints.append([9*wh, 0])
waypoints.append([d+2*wh, W])
waypoints.append([d+3*wh, W])
waypoints.append([10*wh, 0])
waypoints.append([11*wh, 0])
waypoints.append([d+4*wh, W])
waypoints.append([d+5*wh, W])

p = (13*wh-L)*np.tan(theta_rad)
waypoints.append([L, p])
waypoints.append([L, p+wv])
waypoints.append([d+6*wh, W])
waypoints.append([d+7*wh, W])
waypoints.append([L, p+2*wv])
waypoints.append([L, p+3*wv])
waypoints.append([d+8*wh, W])
waypoints.append([d+9*wh, W])
waypoints.append([L, p+4*wv])
waypoints.append([L, p+5*wv])
waypoints.append([d+10*wh, W])
waypoints.append([d+11*wh, W])
    


# ----------- plot figure --------------- 
plt.figure(figsize=(12, 12))
for i in range(len(waypoints) - 1):
    point1 = [waypoints[i][0], waypoints[i+1][0]]
    point2 = [waypoints[i][1], waypoints[i+1][1]]
    plt.plot(point1, point2, '-o', color='black')

# plt.hlines(0, 0, L, lw = 3.0, color='red')
# plt.vlines(0, 0, W, lw = 3.0, color='red')
# plt.hlines(L, 0, L, lw = 3.0, color='red')
# plt.vlines(W, 0, W, lw = 3.0, color='red')

x = [i for i in range(35)]
plt.xticks(x, x)
x = [i for i in range(35)]
plt.yticks(x, x)
plt.show()
